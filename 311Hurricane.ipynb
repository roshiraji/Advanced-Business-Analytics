# %%
import pandas as pd
df = pd.read_csv('311data.csv')

df.head()
# Out:
#          id location_type     incident_address       city    borough  \
# 0  23531046           NaN  111 LAWRENCE STREET   BROOKLYN   BROOKLYN
# 1  23534651        Street        5614 BROADWAY      BRONX      BRONX
# 2  23535556           NaN                  NaN   NEW YORK  MANHATTAN
# 3  23536817           NaN      41-15 45 STREET  SUNNYSIDE     QUEENS
# 4  23536826           NaN   140 EAST 46 STREET   NEW YORK  MANHATTAN
#
#    latitude  longitude    created_date      closed_date agency  \
# 0  40.69283  -73.98623   7/1/2012 3:48  7/26/2012 12:29    TLC
# 1  40.87983  -73.90414  7/2/2012 14:05  7/17/2012 12:35    DOT
# 2  40.73986  -73.97774  7/2/2012 15:28   7/2/2012 21:00    DEP
# 3  40.74641  -73.91898  7/2/2012 11:20    7/6/2012 0:00    DOB
# 4  40.75378  -73.97372   7/2/2012 9:59   9/19/2012 0:00    DOB
#
#                               agency_name     complaint_type  \
# 0           Taxi and Limousine Commission     Taxi Complaint
# ...

# %%
df.describe()
# Out:
#                  id       latitude      longitude
# count  8.155380e+05  815538.000000  815538.000000
# mean   2.413080e+07      40.728566     -73.920981
# std    3.540918e+05       0.087142       0.082524
# min    2.352531e+07      40.498630     -74.254710
# 25%    2.382137e+07      40.664480     -73.964080
# 50%    2.414827e+07      40.720130     -73.924950
# 75%    2.442339e+07      40.807350     -73.874920
# max    3.071714e+07      40.912870     -73.700390

# %%
df.shape
# Out:
# (815538, 14)

# %%
df[df.isna().any(axis=1)]  # check for NaN ('Not a Number') values
# Out:
#               id location_type     incident_address              city  \
# 0       23531046           NaN  111 LAWRENCE STREET          BROOKLYN
# 2       23535556           NaN                  NaN          NEW YORK
# 3       23536817           NaN      41-15 45 STREET         SUNNYSIDE
# 4       23536826           NaN   140 EAST 46 STREET          NEW YORK
# 11      23539393           NaN   NORTHERN BOULEVARD  LONG ISLAND CITY
# ...          ...           ...                  ...               ...
# 815515  24680061        Street                  NaN          BROOKLYN
# 815521  24682662        Street                  NaN          BROOKLYN
# 815522  24683544        Street    222 LOCUST AVENUE     STATEN ISLAND
# 815526  24690219           NaN         95-14 68 AVE      Forest Hills
# 815535  24702974           NaN   259 MELROSE STREET          BROOKLYN
#
#               borough  latitude  longitude      created_date      closed_date  \
# ...

# %%
df = df.dropna(axis=0) # removes rows containing NaN values
df.shape
# Out:
# (542022, 14)

# %%
df.duplicated()
# Out:
# 1         False
# 5         False
# 6         False
# 7         False
# 8         False
#           ...
# 815532    False
# 815533    False
# 815534    False
# 815536    False
# 815537    False
# Length: 542022, dtype: bool

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (542022, 14)

# %%
import datetime
df['created_date'] = pd.to_datetime(df['created_date'])
df['closed_date'] = pd.to_datetime(df['closed_date'])
df['resolution_date'] = pd.to_datetime(df['resolution_date'])

# %%
df.head()
# Out:
#          id               location_type       incident_address         city  \
# 1  23534651                      Street          5614 BROADWAY        BRONX
# 5  23537238     3+ Family Apt. Building  2482 VALENTINE AVENUE        BRONX
# 6  23537297                      Street       242-56 51 AVENUE  LITTLE NECK
# 7  23537396  Residential Building/House   3175 GRAND CONCOURSE        BRONX
# 8  23538127        RESIDENTIAL BUILDING      334 PUTNAM AVENUE     BROOKLYN
#
#     borough  latitude  longitude        created_date         closed_date  \
# 1     BRONX  40.87983  -73.90414 2012-07-02 14:05:00 2012-07-17 12:35:00
# 5     BRONX  40.86169  -73.89612 2012-07-02 00:00:00 2012-07-19 15:17:00
# 6    QUEENS  40.76039  -73.74067 2012-07-02 21:33:00 2012-07-26 17:31:00
# 7     BRONX  40.87611  -73.88587 2012-07-02 22:18:00 2012-07-02 23:13:00
# 8  BROOKLYN  40.68424  -73.94814 2012-07-02 00:00:00 2012-07-12 00:00:00
#
#   agency                                        agency_name  \
# ...

# %%
df.dtypes
# Out:
# id                           int64
# location_type               object
# incident_address            object
# city                        object
# borough                     object
# latitude                   float64
# longitude                  float64
# created_date        datetime64[ns]
# closed_date         datetime64[ns]
# agency                      object
# agency_name                 object
# complaint_type              object
# description                 object
# resolution_date     datetime64[ns]
# dtype: object

# %%
df['location_type'] = df['location_type'].astype("string")

# %%
df.dtypes
# Out:
# id                           int64
# location_type       string[python]
# incident_address            object
# city                        object
# borough                     object
# latitude                   float64
# longitude                  float64
# created_date        datetime64[ns]
# closed_date         datetime64[ns]
# agency                      object
# agency_name                 object
# complaint_type              object
# description                 object
# resolution_date     datetime64[ns]
# dtype: object

# %%
# Define date range
start_date = pd.Timestamp('2012-09-28')
end_date = pd.Timestamp('2012-10-29')

# Filter rows where created_date is between start and end (inclusive)
df_before_sandy = df[df['created_date'].between(start_date, end_date)]

df_before_sandy.head()
# Out:
#            id         location_type      incident_address          city  \
# 759  24105074       Street/Sidewalk  746 CLEVELAND STREET      BROOKLYN
# 760  24105413             Mixed Use  1975 DAVIDSON AVENUE         BRONX
# 761  24106416  RESIDENTIAL BUILDING        607 RUGBY ROAD      BROOKLYN
# 762  24106755      Store/Commercial          757 3 AVENUE      NEW YORK
# 765  24107444  RESIDENTIAL BUILDING     31-10 LEWMAY ROAD  FAR ROCKAWAY
#
#        borough  latitude  longitude        created_date         closed_date  \
# 759   BROOKLYN  40.66592  -73.88211 2012-09-28 16:00:00 2012-09-28 17:40:00
# 760      BRONX  40.85234  -73.90987 2012-09-28 15:06:00 2012-10-11 00:00:00
# 761   BROOKLYN  40.63461  -73.96411 2012-09-28 00:00:00 2012-10-03 00:00:00
# 762  MANHATTAN  40.75404  -73.97205 2012-09-28 21:47:00 2012-09-28 23:48:00
# 765     QUEENS  40.59400  -73.76373 2012-09-28 00:00:00 2012-10-04 00:00:00
#
#     agency                                        agency_name  \
# ...

# %%
df_before_sandy.tail()
# Out:
#               id               location_type         incident_address  \
# 814913  24275814  Residential Building/House         93-10 208 STREET
# 814914  24277476  Residential Building/House          20-78 28 STREET
# 814915  24278087        RESIDENTIAL BUILDING            553 46 STREET
# 815536  26816391  Residential Building/House       315 WEST 33 STREET
# 815537  26827724              Street Address  89-25 PARSONS BOULEVARD
#
#                   city    borough  latitude  longitude        created_date  \
# 814913  QUEENS VILLAGE     QUEENS  40.71667  -73.75394 2012-10-28 01:45:00
# 814914         ASTORIA     QUEENS  40.77954  -73.90969 2012-10-27 22:06:00
# 814915        BROOKLYN   BROOKLYN  40.64666  -74.00684 2012-10-27 00:00:00
# 815536        NEW YORK  MANHATTAN  40.75183  -73.99465 2012-10-16 02:30:00
# 815537         JAMAICA     QUEENS  40.70547  -73.80147 2012-10-16 15:28:00
#
#                closed_date agency  \
# 814913 2012-10-28 02:33:00   NYPD
# ...

# %%
# Define date range
sandy_start_date = pd.Timestamp('2012-10-30')
sandy_end_date = pd.Timestamp('2012-12-01')

# Filter rows where created_date is between start and end (inclusive)
df_after_sandy = df[df['created_date'].between(start_date, end_date)]

df_after_sandy.head()
# Out:
#            id         location_type      incident_address          city  \
# 759  24105074       Street/Sidewalk  746 CLEVELAND STREET      BROOKLYN
# 760  24105413             Mixed Use  1975 DAVIDSON AVENUE         BRONX
# 761  24106416  RESIDENTIAL BUILDING        607 RUGBY ROAD      BROOKLYN
# 762  24106755      Store/Commercial          757 3 AVENUE      NEW YORK
# 765  24107444  RESIDENTIAL BUILDING     31-10 LEWMAY ROAD  FAR ROCKAWAY
#
#        borough  latitude  longitude        created_date         closed_date  \
# 759   BROOKLYN  40.66592  -73.88211 2012-09-28 16:00:00 2012-09-28 17:40:00
# 760      BRONX  40.85234  -73.90987 2012-09-28 15:06:00 2012-10-11 00:00:00
# 761   BROOKLYN  40.63461  -73.96411 2012-09-28 00:00:00 2012-10-03 00:00:00
# 762  MANHATTAN  40.75404  -73.97205 2012-09-28 21:47:00 2012-09-28 23:48:00
# 765     QUEENS  40.59400  -73.76373 2012-09-28 00:00:00 2012-10-04 00:00:00
#
#     agency                                        agency_name  \
# ...

# %%
df_after_sandy.tail()
# Out:
#               id               location_type         incident_address  \
# 814913  24275814  Residential Building/House         93-10 208 STREET
# 814914  24277476  Residential Building/House          20-78 28 STREET
# 814915  24278087        RESIDENTIAL BUILDING            553 46 STREET
# 815536  26816391  Residential Building/House       315 WEST 33 STREET
# 815537  26827724              Street Address  89-25 PARSONS BOULEVARD
#
#                   city    borough  latitude  longitude        created_date  \
# 814913  QUEENS VILLAGE     QUEENS  40.71667  -73.75394 2012-10-28 01:45:00
# 814914         ASTORIA     QUEENS  40.77954  -73.90969 2012-10-27 22:06:00
# 814915        BROOKLYN   BROOKLYN  40.64666  -74.00684 2012-10-27 00:00:00
# 815536        NEW YORK  MANHATTAN  40.75183  -73.99465 2012-10-16 02:30:00
# 815537         JAMAICA     QUEENS  40.70547  -73.80147 2012-10-16 15:28:00
#
#                closed_date agency  \
# 814913 2012-10-28 02:33:00   NYPD
# ...

# %%
df_after_sandy['agency'].value_counts()
# Out:
# agency
# HPD      45469
# NYPD     23832
# DSNY      6996
# DOT       3379
# DPR       3302
# DOHMH     2943
# FDNY       564
# DOB        495
# TLC        448
# DOE         98
# DOITT       84
# EDC         50
# Name: count, dtype: int64

# %%
df_after_sandy['agency_name'].value_counts()
# Out:
# agency_name
# Department of Housing Preservation and Development               45469
# New York City Police Department                                  23832
# Department of Transportation                                      3379
# Department of Parks and Recreation                                3302
# Department of Health and Mental Hygiene                           2943
#                                                                  ...
# School - PS 116 Elizabeth L Farrell                                  1
# School - JHS 74 Nathaniel Hawthorne                                  1
# School - Pelham Academy of Academics and Community Engagement        1
# School - PS 129 Twin Parks Upper                                     1
# School - PS 92 Mary McLeod Bethune                                   1
# Name: count, Length: 128, dtype: int64

# %%
df_before_sandy['agency_name'].value_counts()
# Out:
# agency_name
# Department of Housing Preservation and Development               45469
# New York City Police Department                                  23832
# Department of Transportation                                      3379
# Department of Parks and Recreation                                3302
# Department of Health and Mental Hygiene                           2943
#                                                                  ...
# School - PS 116 Elizabeth L Farrell                                  1
# School - JHS 74 Nathaniel Hawthorne                                  1
# School - Pelham Academy of Academics and Community Engagement        1
# School - PS 129 Twin Parks Upper                                     1
# School - PS 92 Mary McLeod Bethune                                   1
# Name: count, Length: 128, dtype: int64
